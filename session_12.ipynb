# %%
import numpy as np 
import pandas as pd

# %%
# 1. Install Seaborn in your Python environment and use it to create a histplot showing the distribution of 
# delivery times (in minutes) for 50 Zomato food orders. Generate random data if needed.

import seaborn as sns 

print(sns.__version__)

a = np.random.randint(100,1000,50)
sns.histplot(a )
# Out:
# 0.13.2
# <Axes: ylabel='Count'>

# %%
# 2.Load the 'tips' dataset from Seaborn and create a boxplot to visualize the distribution of total bill amounts by 
# day of the week, similar to how Zomato might analyze spending patterns across weekdays.


data = pd.DataFrame(
    {
        "tips":np.random.randint(1,100,40)
    }
)

data.loc[4,'tips'] = 500
data.loc[33,'tips'] = 300
data.loc[43 , 'tips'] = -200
data.loc[19 , 'tips'] = -100

sns.boxplot(data)
# Out:
# <Axes: >

# %%
# 3.# Simulate IPL match scores for 8 teams and use a violinplot to compare the run distributions per team. 
# Style your plot using the 'darkgrid' Seaborn theme.

ipl = pd.read_csv(r"D:\Tops Technowlogy\Data Scince\Dummy_Library_Assignment\csv_files\ipl_match_scores.csv")


violinplot1  =  sns.violinplot(data = ipl['Runs'])

# %%
# 4. Create a countplot that displays the number of songs per genre from a list of 40 Spotify tracks, with at least 4 
# different genres represented.<br><br><em><strong>Hint:</strong> Use a Python list or pandas DataFrame to store your 
# data, then plot with Seaborn.</em>

df = pd.read_csv(r"D:\Tops Technowlogy\Data Scince\Dummy_Library_Assignment\csv_files\spotify_playlists.csv")
sns.countplot(x='total_tracks',data = df)
# Out:
# <Axes: xlabel='total_tracks', ylabel='count'>

# %%
# 5.# Use Seaborn's kdeplot to visualize the distribution of daily step counts for a week, as if analyzing data from a
#  fitness app. Apply the 'whitegrid' theme and customize the plot color.

steps = np.random.randint(1000,10000,7)
steps = pd.DataFrame({
    'steps':steps
})

sns.set_style(style='whitegrid')
sns.kdeplot(steps,color='green')
# Out:
# <Axes: ylabel='Density'>
